# %%
! pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.3.56-cp38-cp38-win_amd64.whl (34.9 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\anaconda3\lib\site-packages (from opencv-python) (1.20.1)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.3.56

# %%
import os
import cv2 
import csv

# xml 파일 파싱 라이브러리 
import xml.etree.ElementTree as ET
from xml.etree.ElementTree import Element, dump, ElementTree

# %%
# xml 파일 불러오기

fileDir = "C://Users//김영민//Downloads//이상행동 CCTV 영상" # 데이터셋 저장 경로
fileExt = ".xml" # 확장자명

frame = []
count = 0 # count 번째 사진 

for category in os.listdir(fileDir) : # 이상행위 별 폴더
    for split in os.listdir(fileDir + "//" + category) : # 해당 이상행위 영상 분할압축 폴더 중 다운로드 받은 파일 폴더
        for folder in os.listdir(fileDir + "//" + category + "//" + split) :
            for file in os.listdir(fileDir + "//" + category + "//" + split + "//" + folder) :
                if file.endswith(fileExt) : # 파일명에 .xml 이 포함된 경우 
                    xml_file = fileDir + "//" + category + "//" + split + "//" + folder + "//" + file
                    doc = ET.parse(xml_file)
                    root = doc.getroot() # root 노드 가지고 오기
                    
                    # xml 파일에서 시작/끝 프레임 수 추출
                    for object in root.iter("action"):
                        start = int(object.find("frame").findtext("start"))
                        end = int(object.find("frame").findtext("end"))

                        framelist = [start, end]
                        frame.append(framelist)
                    
                    for i in range(len(frame)) :
                        filename = file[:-4]
                        print(filename)

                        video = fileDir + "//" + category + "//" + split + "//" + folder + "//" + filename + ".mp4"
                        savepath = "C://cap//" + category # 경로에 한글 포함되면 안됨
                        
                        # 기존에 frame dir가 없는 경우, 해당 dir를 생성한다.
                        if not os.path.exists(savepath):
                            os.makedirs(savepath)

                        vidcap = cv2.VideoCapture(video)

                        fps = vidcap.get(cv2.CAP_PROP_FPS)
                        frame_count = vidcap.get(cv2.CAP_PROP_FRAME_COUNT) 
                        duration = frame_count / fps 

                        increase_width = 5 # 스크린샷 캡처 간격 설정
                        start_frame = frame[i][0] 
                        success = True
                        
                        while success :
                            vidcap.set(1, start_frame)
                            success,image = vidcap.read() 
                            image = cv2.resize(image, (960, 540))
                            print(start_frame, "번째 프레임 캡쳐") 
                            cv2.imwrite(savepath + "//%d.jpg"%count, image) # 저장시킬 위치 주소 
                            print("saved image %d.jpg" % count)
                            count += 1
                            start_frame += increase_width 
                            if start_frame > frame[i][1] :
                                break 

                        print('----- Finish Video Capture! -----')
# Out:
# 488-1_cam01_vandalism01_place09_day_spring
# 7969 번째 프레임 캡쳐
# saved image 0.jpg
# 7974 번째 프레임 캡쳐
# saved image 1.jpg
# 7979 번째 프레임 캡쳐
# saved image 2.jpg
# 7984 번째 프레임 캡쳐
# saved image 3.jpg
# 7989 번째 프레임 캡쳐
# saved image 4.jpg
# 7994 번째 프레임 캡쳐
# saved image 5.jpg
# 7999 번째 프레임 캡쳐
# saved image 6.jpg
# 8004 번째 프레임 캡쳐
# saved image 7.jpg
# 8009 번째 프레임 캡쳐
# saved image 8.jpg
# 8014 번째 프레임 캡쳐
# saved image 9.jpg
# 8019 번째 프레임 캡쳐
# saved image 10.jpg
# 8024 번째 프레임 캡쳐
# saved image 11.jpg
# 8029 번째 프레임 캡쳐
# saved image 12.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_spring
# 9082 번째 프레임 캡쳐
# saved image 13.jpg
# 9087 번째 프레임 캡쳐
# saved image 14.jpg
# 9092 번째 프레임 캡쳐
# saved image 15.jpg
# 9097 번째 프레임 캡쳐
# saved image 16.jpg
# 9102 번째 프레임 캡쳐
# saved image 17.jpg
# 9107 번째 프레임 캡쳐
# saved image 18.jpg
# 9112 번째 프레임 캡쳐
# saved image 19.jpg
# 9117 번째 프레임 캡쳐
# saved image 20.jpg
# 9122 번째 프레임 캡쳐
# saved image 21.jpg
# 9127 번째 프레임 캡쳐
# saved image 22.jpg
# 9132 번째 프레임 캡쳐
# saved image 23.jpg
# 9137 번째 프레임 캡쳐
# saved image 24.jpg
# 9142 번째 프레임 캡쳐
# saved image 25.jpg
# 9147 번째 프레임 캡쳐
# saved image 26.jpg
# 9152 번째 프레임 캡쳐
# saved image 27.jpg
# 9157 번째 프레임 캡쳐
# saved image 28.jpg
# 9162 번째 프레임 캡쳐
# saved image 29.jpg
# 9167 번째 프레임 캡쳐
# saved image 30.jpg
# 9172 번째 프레임 캡쳐
# saved image 31.jpg
# 9177 번째 프레임 캡쳐
# saved image 32.jpg
# 9182 번째 프레임 캡쳐
# saved image 33.jpg
# 9187 번째 프레임 캡쳐
# saved image 34.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_summer
# 7969 번째 프레임 캡쳐
# saved image 35.jpg
# 7974 번째 프레임 캡쳐
# saved image 36.jpg
# 7979 번째 프레임 캡쳐
# saved image 37.jpg
# 7984 번째 프레임 캡쳐
# saved image 38.jpg
# 7989 번째 프레임 캡쳐
# saved image 39.jpg
# 7994 번째 프레임 캡쳐
# saved image 40.jpg
# 7999 번째 프레임 캡쳐
# saved image 41.jpg
# 8004 번째 프레임 캡쳐
# saved image 42.jpg
# 8009 번째 프레임 캡쳐
# saved image 43.jpg
# 8014 번째 프레임 캡쳐
# saved image 44.jpg
# 8019 번째 프레임 캡쳐
# saved image 45.jpg
# 8024 번째 프레임 캡쳐
# saved image 46.jpg
# 8029 번째 프레임 캡쳐
# saved image 47.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_summer
# 9082 번째 프레임 캡쳐
# saved image 48.jpg
# 9087 번째 프레임 캡쳐
# saved image 49.jpg
# 9092 번째 프레임 캡쳐
# saved image 50.jpg
# 9097 번째 프레임 캡쳐
# saved image 51.jpg
# 9102 번째 프레임 캡쳐
# saved image 52.jpg
# 9107 번째 프레임 캡쳐
# saved image 53.jpg
# 9112 번째 프레임 캡쳐
# saved image 54.jpg
# 9117 번째 프레임 캡쳐
# saved image 55.jpg
# 9122 번째 프레임 캡쳐
# saved image 56.jpg
# 9127 번째 프레임 캡쳐
# saved image 57.jpg
# 9132 번째 프레임 캡쳐
# saved image 58.jpg
# 9137 번째 프레임 캡쳐
# saved image 59.jpg
# 9142 번째 프레임 캡쳐
# saved image 60.jpg
# 9147 번째 프레임 캡쳐
# saved image 61.jpg
# 9152 번째 프레임 캡쳐
# saved image 62.jpg
# 9157 번째 프레임 캡쳐
# saved image 63.jpg
# 9162 번째 프레임 캡쳐
# saved image 64.jpg
# 9167 번째 프레임 캡쳐
# saved image 65.jpg
# 9172 번째 프레임 캡쳐
# saved image 66.jpg
# 9177 번째 프레임 캡쳐
# saved image 67.jpg
# 9182 번째 프레임 캡쳐
# saved image 68.jpg
# 9187 번째 프레임 캡쳐
# saved image 69.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_summer
# 9567 번째 프레임 캡쳐
# saved image 70.jpg
# 9572 번째 프레임 캡쳐
# saved image 71.jpg
# 9577 번째 프레임 캡쳐
# saved image 72.jpg
# 9582 번째 프레임 캡쳐
# saved image 73.jpg
# 9587 번째 프레임 캡쳐
# saved image 74.jpg
# 9592 번째 프레임 캡쳐
# saved image 75.jpg
# 9597 번째 프레임 캡쳐
# saved image 76.jpg
# 9602 번째 프레임 캡쳐
# saved image 77.jpg
# 9607 번째 프레임 캡쳐
# saved image 78.jpg
# 9612 번째 프레임 캡쳐
# saved image 79.jpg
# 9617 번째 프레임 캡쳐
# saved image 80.jpg
# 9622 번째 프레임 캡쳐
# saved image 81.jpg
# 9627 번째 프레임 캡쳐
# saved image 82.jpg
# 9632 번째 프레임 캡쳐
# saved image 83.jpg
# 9637 번째 프레임 캡쳐
# saved image 84.jpg
# 9642 번째 프레임 캡쳐
# saved image 85.jpg
# 9647 번째 프레임 캡쳐
# saved image 86.jpg
# 9652 번째 프레임 캡쳐
# saved image 87.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_summer
# 9811 번째 프레임 캡쳐
# saved image 88.jpg
# 9816 번째 프레임 캡쳐
# saved image 89.jpg
# 9821 번째 프레임 캡쳐
# saved image 90.jpg
# 9826 번째 프레임 캡쳐
# saved image 91.jpg
# 9831 번째 프레임 캡쳐
# saved image 92.jpg
# 9836 번째 프레임 캡쳐
# saved image 93.jpg
# 9841 번째 프레임 캡쳐
# saved image 94.jpg
# 9846 번째 프레임 캡쳐
# saved image 95.jpg
# 9851 번째 프레임 캡쳐
# saved image 96.jpg
# 9856 번째 프레임 캡쳐
# saved image 97.jpg
# 9861 번째 프레임 캡쳐
# saved image 98.jpg
# 9866 번째 프레임 캡쳐
# saved image 99.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_winter
# 7969 번째 프레임 캡쳐
# saved image 100.jpg
# 7974 번째 프레임 캡쳐
# saved image 101.jpg
# 7979 번째 프레임 캡쳐
# saved image 102.jpg
# 7984 번째 프레임 캡쳐
# saved image 103.jpg
# 7989 번째 프레임 캡쳐
# saved image 104.jpg
# 7994 번째 프레임 캡쳐
# saved image 105.jpg
# 7999 번째 프레임 캡쳐
# saved image 106.jpg
# 8004 번째 프레임 캡쳐
# saved image 107.jpg
# 8009 번째 프레임 캡쳐
# saved image 108.jpg
# 8014 번째 프레임 캡쳐
# saved image 109.jpg
# 8019 번째 프레임 캡쳐
# saved image 110.jpg
# 8024 번째 프레임 캡쳐
# saved image 111.jpg
# 8029 번째 프레임 캡쳐
# saved image 112.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_winter
# 9082 번째 프레임 캡쳐
# saved image 113.jpg
# 9087 번째 프레임 캡쳐
# saved image 114.jpg
# 9092 번째 프레임 캡쳐
# saved image 115.jpg
# 9097 번째 프레임 캡쳐
# saved image 116.jpg
# 9102 번째 프레임 캡쳐
# saved image 117.jpg
# 9107 번째 프레임 캡쳐
# saved image 118.jpg
# 9112 번째 프레임 캡쳐
# saved image 119.jpg
# 9117 번째 프레임 캡쳐
# saved image 120.jpg
# 9122 번째 프레임 캡쳐
# saved image 121.jpg
# 9127 번째 프레임 캡쳐
# saved image 122.jpg
# 9132 번째 프레임 캡쳐
# saved image 123.jpg
# 9137 번째 프레임 캡쳐
# saved image 124.jpg
# 9142 번째 프레임 캡쳐
# saved image 125.jpg
# 9147 번째 프레임 캡쳐
# saved image 126.jpg
# 9152 번째 프레임 캡쳐
# saved image 127.jpg
# 9157 번째 프레임 캡쳐
# saved image 128.jpg
# 9162 번째 프레임 캡쳐
# saved image 129.jpg
# 9167 번째 프레임 캡쳐
# saved image 130.jpg
# 9172 번째 프레임 캡쳐
# saved image 131.jpg
# 9177 번째 프레임 캡쳐
# saved image 132.jpg
# 9182 번째 프레임 캡쳐
# saved image 133.jpg
# 9187 번째 프레임 캡쳐
# saved image 134.jpg
# ----- Finish Video Capture! -----
# 488-1_cam01_vandalism01_place09_day_winter
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-c41218476270> in <module>
#      48                             vidcap.set(1, start_frame)
#      49                             success,image = vidcap.read()
# ---> 50                             image = cv2.resize(image, (960, 540))
#      51                             print(start_frame, "번째 프레임 캡쳐")
#      52                             cv2.imwrite(savepath + "//%d.jpg"%count, image) # 저장시킬 위치 주소
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-q3d_8t8e\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
